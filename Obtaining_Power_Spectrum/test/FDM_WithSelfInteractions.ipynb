# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.integrate import solve_ivp

# %% [markdown]
# From **linear perturbation theory**
#
# We know that the evolution of density perturbations in a universe dominated by fuzzy dark matter (FDM) without self-interactions can be described by the following differential equation:
# \begin{equation}
# \ddot{\delta_k} + 2 H \dot {\delta_k} - \left[\frac{h^{2}k^{4}}{4 m^{2} a^{4}} - \frac{4 \pi G \bar{\rho_m}(t)}{a^{3}(t)} - \frac{3 \lambda \bar{\rho_{m}}(t) k ^{2}}{8 m^{4}a^{2}} \right]\delta_{k} = 0
# \end{equation}
#
# For reference, see Cosmological Simulation for Fuzzy by Dark Matter Model by Jiajun Zhang, Hantao Liu and Ming-Chung Chu (2019)

# %% [markdown]
# **For matter dominant universe**
#
# We have
# \begin{equation}
# a(t) \propto t^{2/3}
# \end{equation}
# and therefore
# \begin{equation}
# H(t) = \frac{2}{3t}
# \end{equation}
#
# The average matter density is also given as
# \begin{equation}
# \bar{\rho_{t}} = \frac{1}{6 \pi G t^{2}}
# \end{equation}

# %%
output_path = '/home/isha/Desktop/AU/Work_Done/Wave_Dark_Matter/Obtaining_Power_Spectrum/'

# %%
# !pwd
# Out:
# /home/isha/Desktop/AU/Work_Done/Wave_Dark_Matter/Obtaining_Power_Spectrum

# %%
#Constant Parameters
hbar = 6.582e-16    # eV s
h = 0.674
G = 4.30091e-9     #Mpc Msun^-1 (km/s)^2
m = 1e-22    #FDM paricle mass in eV

# %%
k_pow = np.arange(-6, 4)   #Mpc^-1
k = 10.0 ** k_pow

length_scale = 2 * np.pi / k    #Mpc
k, length_scale
# Out:
# (array([1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01,
#         1.e+02, 1.e+03]),
#  array([6.28318531e+06, 6.28318531e+05, 6.28318531e+04, 6.28318531e+03,
#         6.28318531e+02, 6.28318531e+01, 6.28318531e+00, 6.28318531e-01,
#         6.28318531e-02, 6.28318531e-03]))

# %% [markdown]
# **For one specific mode i.e. k = 1 Mpc^-1**

# %%
i = 6
k_sel = k[i]
length_scale_sel = length_scale[i]

print(f'k: {k_sel} Mpc^-1 |  length_scale: {length_scale_sel} Mpc')
# Out:
# k: 1.0 Mpc^-1 |  length_scale: 6.283185307179586 Mpc

# %% [markdown]
# **Define initial conditions a early times**
#
# \begin{equation}
# \delta (t) \propto a (t) \propto t^{2/3}
# \end{equation}
#
# Therefore,
# \begin{equation}
# \dot{\delta} (t) = \frac{2 \delta}{3t}
# \end{equation}

# %%
def a(t):
    return t**(2/3)

def rho_m(t):
    return 1 / (6 * np.pi * G * t**2)   #Msun Mpc^-3

def H(t):
    return 2 / (3 * t)

lambda_param = -3e-7  #Self-interaction coupling constant

# %%
#Setup the ODE
#Convert the 2nd order ODE into a system of first order ODEs
def ode_fdm_si(t, y):
    u1, u2 = y      #u1 = delta | u2 = delta_dot
    
    H = 2 / (3 * t)
    quantum_term = (hbar**2 * k_sel**4) / (4 * m**2 * a(t)**4)
    grav_term = 2 / (3 * t**2 * a(t)**3)
    selfinteraction_term = (3 * lambda_param * rho_m(t) * k_sel**2) / (8 * m**4 * a(t)**2)

    #Solve the following coupled 1st order ODEs
    du1_dt = u2
    du2_dt_fdm = -2*H(t)*u2 + (grav_term - quantum_term - selfinteraction_term)*u1
    return [du1_dt, du2_dt_fdm]


def ode_cdm(t, y):
    u1, u2 = y      #u1 = delta | u2 = delta_dot
    
    H = 2 / (3 * t)
    grav_term = 2 / (3 * t**2 * a(t)**3)

    #Solve the following coupled 1st order ODEs
    du1_dt = u2
    du2_dt_cdm = -2*H(t)*u2 + grav_term*u1
    return [du1_dt, du2_dt_cdm]

# %%
#Initial Conditions and Time Span
t_i = 1e-2
t_f = 100
t_span = [t_i, t_f]   #Starting and ending interval for t
t_eval = np.logspace(np.log10(t_i), np.log10(t_f), 500)   #Times at which to store the computed solution

delta0 = 1    #Arbitrarily chosen presently
delta_dot0 = (2/(3*t_i)) * delta0

initial_conditions = [delta0, delta_dot0]
initial_conditions
# Out:
# [1, 66.66666666666667]

# %%
fig, ax  = plt.subplots(1, 2, figsize=(12,5))
ax[0].plot(t_eval, a(t_eval), label='Scale Factor a(t)')
ax[1].loglog(t_eval, a(t_eval), label='Scale Factor log a(t)')
ax[0].set_xlabel('t')
ax[0].set_ylabel('Scale Factor a(t)')
ax[1].set_xlabel('t')
ax[1].set_ylabel('log a(t)')

#Note that during matter dominant era, CDM density perturbations must follow behaviour of a(t)
# Out:
# Text(0, 0.5, 'log a(t)')

# %%
# Solve the ODE
solve_cdm = solve_ivp(ode_cdm, t_span, initial_conditions, t_eval = t_eval)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 # Solve the ODE
# ----> 2 solve_cdm = solve_ivp(ode_cdm, t_span, initial_conditions, t_eval = t_eval)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:557, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     554 if method in METHODS:
#     555     method = METHODS[method]
# --> 557 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     559 if t_eval is None:
#     560     ts = [t0]
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[63], line 25, in ode_cdm(t, y)
#      23 #Solve the following coupled 1st order ODEs
#      24 du1_dt = u2
# ---> 25 du2_dt_cdm = -2*H(t)*u2 + grav_term*u1
#      26 return [du1_dt, du2_dt_cdm]
#
# TypeError: 'float' object is not callable

# %%
t = solve_cdm.t
delta0_cdm, delta0_dot_cdm = solve_cdm.y[0], solve_cdm.y[1]

# Plot
plt.loglog(t, delta0_cdm,  label="CDM density perturbations")
plt.loglog(t, delta0_dot_cdm,  label="CDM growth rate")
plt.legend()
plt.grid(True)
plt.xlabel("t")
plt.ylabel(r"Density and Growth Rate")
plt.title(f" (k = {k_sel:.1e} Mpc$^{{-1}}$)")
#plt.savefig(output_path + f'cdm_density_growth_k={int(k_sel)}Mpc-inv.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 t = solve_cdm.t
#       2 delta0_cdm, delta0_dot_cdm = solve_cdm.y[0], solve_cdm.y[1]
#       4 # Plot
#
# NameError: name 'solve_cdm' is not defined

# %%
solve_fdm_si = solve_ivp(ode_fdm_si, t_span, initial_conditions, t_eval = t_eval)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 solve_fdm_si = solve_ivp(ode_fdm_si, t_span, initial_conditions, t_eval = t_eval)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:557, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     554 if method in METHODS:
#     555     method = METHODS[method]
# --> 557 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     559 if t_eval is None:
#     560     ts = [t0]
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[18], line 13, in ode_fdm_si(t, y)
#      11 #Solve the following coupled 1st order ODEs
#      12 du1_dt = u2
# ---> 13 du2_dt_fdm = -2*H(t)*u2 + (grav_term - quantum_term - selfinteraction_term)*u1
#      14 return [du1_dt, du2_dt_fdm]
#
# TypeError: 'float' object is not callable

# %%
t = solve_fdm_si.t
delta0_fdm_si, delta0_dot_fdm_si = solve_fdm.y[0], solve_fdm.y[1]

# Plot
plt.loglog(t, delta0_fdm_si, label="FDM+SI density perturbations")
plt.loglog(t, delta0_dot_fdm_si,  label="FDM+SI growth rate")
plt.legend()
plt.grid(True)
plt.xlabel("t")
plt.ylabel(r"Density and Growth Rate")
plt.title(f" (k = {k_sel:.1e} Mpc$^{{-1}}$)")
plt.savefig(output_path + f'fdm_si_density_growth_k={int(k_sel)}Mpc-inv.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t = solve_fdm_si.t
#       2 delta0_fdm_si, delta0_dot_fdm_si = solve_fdm.y[0], solve_fdm.y[1]
#       4 # Plot
#
# NameError: name 'solve_fdm_si' is not defined

# %%
#Saving the results
df = pd.DataFrame({
    't': t,
    'delta0_fdm': delta0_fdm_si,
    'delta0_dot_fdm': delta0_dot_fdm_si,
    'delta0_cdm': delta0_cdm,
    'delta0_dot_cdm': delta0_dot_cdm
})
df.to_csv(output_path +"fdm_si_vs_cdm_density_growth.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #Saving the results
#       2 df = pd.DataFrame({
# ----> 3     't': t,
#       4     'delta0_fdm': delta0_fdm,
#       5     'delta0_dot_fdm': delta0_dot_fdm,
#       6     'delta0_cdm': delta0_cdm,
#       7     'delta0_dot_cdm': delta0_dot_cdm
#       8 })
#       9 df.to_csv(output_path +"fdm_vs_cdm_density_growth.csv", index=False)
#
# NameError: name 't' is not defined

# %%
df =  pd.read_csv(output_path +"fdm_si_vs_cdm_density_growth.csv")

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].loglog(df['t'], df['delta0_cdm'], label="CDM density perturbations")
ax[0].loglog(df['t'], df['delta0_fdm'],   label="FDM+SI density perturbations")
ax[1].loglog(df['t'], df['delta0_dot_cdm'],  label="CDM growth rate")
ax[1].loglog(df['t'], df['delta0_dot_fdm'],  label="FDM+SI growth rate")
ax[0].set_ylabel(r"Density Perturbations")
ax[1].set_ylabel(r"Growth Rate")

ax[0].set_xlabel(r"$t$")
ax[1].set_xlabel(r"$t$")
ax[0].grid(True)
ax[1].grid(True)
ax[0].legend()
ax[1].legend()
fig.suptitle(f"Density Perturbations and Growth Rate Comparison (k = {k_sel:.1e} Mpc$^{{-1}}$)")
fig.savefig(output_path + f'fdm_si_vs_cdm_density_growth_k={int(k_sel)}Mpc-inv.png', dpi=300)
plt.show()

# %% [markdown]
# **Note:** The code above needs to be fixed for self-interaction terms.
#
# **For multiple modes**
#
# - To obtain a power spectrum for FDM, we need to repeat above steps for the entire range of k values.
# - Is it necessary to estimate a transfer function for FDM? If yes, how is it to be implemented?
# - Note that we are only doing the above procedure for matter-dominant time period. Isnt inclusion of radiation dominant era also necessary when evolving using the primordial power spectrum as initial condition?
# - How to use the primordial power spectrum as an initial condition? In which step? Refer to documentation on CAMB.

# %%
#TEST
#Note that below, I have not used transfer functions to set initial conditions for different k modes.
#This is just to test the code for solving ODEs for multiple k values.

k_pow = np.arange(-3, 3)   #Mpc^-1
k_val = 10.0 ** k_pow

#Setting the values of hbar and m to 1 to test the code below
hbar = 1
m = 1
c = 1
G = 4.30091**(-9)     #Mpc Msun^-1 (km/s)^2
lambda_param = -3e-7  #Self-interaction coupling constant

# %%
def ode_fdm_si_allkvals(t, y, k):
    u1, u2 = y      #u1 = delta | u2 = delta_dot
    
    H = 2 / (3 * t)
    quantum_term = (hbar**2 * k**4) / (4 * m**2 * a(t)**4)
    grav_term = 2 / (3 * t**2 * a(t)**3)
    selfinteraction_term = (3 * lambda_param * rho_m(t) * k_sel**2) / (8 * m**4 * a(t)**2)


    #Solve the following coupled 1st order ODEs
    du1_dt = u2
    du2_dt_fdm = -2*H(t)*u2 + (grav_term - quantum_term - selfinteraction_term)*u1
    return [du1_dt, du2_dt_fdm]


fdm_si_allkvals = []
for k_i in k_val:
    sol_fdm_si = solve_ivp(
        ode_fdm_si_allkvals,
        t_span,
        initial_conditions,
        t_eval=t_eval,
        args=(k_i,),
        #method = 'LSODA'
    )

    for j in range(len(t_eval)):
        fdm_allkvals.append(
            {
                't': t_eval[j],
                'k': k_i,
                'delta_fdm': sol_fdm_si.y[0][j],
                'delta_dot_fdm': sol_fdm_si.y[1][j]
            }
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 18
#      16 fdm_si_allkvals = []
#      17 for k_i in k_val:
# ---> 18     sol_fdm_si = solve_ivp(
#      19         ode_fdm_si_allkvals,
#      20         t_span,
#      21         initial_conditions,
#      22         t_eval=t_eval,
#      23         args=(k_i,),
#      24         #method = 'LSODA'
#      25     )
#      27     for j in range(len(t_eval)):
#      28         fdm_allkvals.append(
#      29             {
#      30                 't': t_eval[j],
#    (...)
#      34             }
#      35         )
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:557, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     554 if method in METHODS:
#     555     method = METHODS[method]
# --> 557 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     559 if t_eval is None:
#     560     ts = [t0]
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:529, in solve_ivp.<locals>.<lambda>(t, x, fun)
#     523     suggestion_tuple = (
#     524         "Supplied 'args' cannot be unpacked. Please supply `args`"
#     525         f" as a tuple (e.g. `args=({args},)`)"
#     526     )
#     527     raise TypeError(suggestion_tuple) from exp
# --> 529 fun = lambda t, x, fun=fun: fun(t, x, *args)
#     530 jac = options.get('jac')
#     531 if callable(jac):
#
# Cell In[75], line 12, in ode_fdm_si_allkvals(t, y, k)
#      10 #Solve the following coupled 1st order ODEs
#      11 du1_dt = u2
# ---> 12 du2_dt_fdm = -2*H(t)*u2 + (grav_term - quantum_term - selfinteraction_term)*u1
#      13 return [du1_dt, du2_dt_fdm]
#
# TypeError: 'float' object is not callable

# %%
def ode_cdm_allkvals(t, y, k):
    u1, u2 = y      #u1 = delta | u2 = delta_dot
    
    H = 2 / (3 * t)
    quantum_term = 0
    grav_term = 2 / (3 * t**2 * a(t)**3)

    #Solve the following coupled 1st order ODEs
    du1_dt = u2
    du2_dt_cdm = -2*H*u2 + (grav_term - quantum_term)*u1
    return [du1_dt, du2_dt_cdm]


cdm_allkvals = []
for k_i in k_val:
    sol_cdm = solve_ivp(
        ode_cdm_allkvals,
        t_span,
        initial_conditions,
        t_eval=t_eval,
        args=(k_i,),
        #method = 'LSODA'
    )

    for j in range(len(t_eval)):
        cdm_allkvals.append(
            {
                't': t_eval[j],
                'k': k_i,
                'delta_cdm': sol_cdm.y[0][j],
                'delta_dot_cdm': sol_cdm.y[1][j]
            }
        )

# %%
df_fdm_si_allkvals = pd.DataFrame(fdm_si_allkvals)
df_cdm_allkvals = pd.DataFrame(cdm_allkvals)

df_fdm_si_allkvals.to_csv(output_path + 'fdm_si_density_growth_allkvals.csv', index=False)
#df_cdm_allkvals.to_csv(output_path + 'cdm_density_growth_allkvals.csv', index=False)

# %%
df_fdm_si_allkvals.columns
# Out:
# Index([], dtype='object')

# %%
#Obtaining power spectrum for last value of t for all k values
t_final_fdm_si = df_fdm_si_allkvals['t'].max()
t_final_cdm = df_cdm_allkvals['t'].max()

df_fdm_si_final = df_fdm_si_allkvals[df_fdm_si_allkvals['t'] == t_final_fdm_si]
df_cdm_final = df_cdm_allkvals[df_cdm_allkvals['t'] == t_final_cdm]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 't'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 #Obtaining power spectrum for last value of t for all k values
# ----> 2 t_final_fdm_si = df_fdm_si_allkvals['t'].max()
#       3 t_final_cdm = df_cdm_allkvals['t'].max()
#       5 df_fdm_si_final = df_fdm_si_allkvals[df_fdm_si_allkvals['t'] == t_final_fdm_si]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 't'

# %%
#As P(k) values are proportional to |delta(k)|^2
df_fdm_si_final['P_k'] = df_fdm_si_final['delta_fdm'] **2
df_cdm_final['P_k'] = df_cdm_final['delta_cdm'] **2

# %%
plt.plot(df_fdm_si_final['k'], df_fdm_si_final['P_k'], label='FDM+SI')
plt.plot(df_cdm_final['k'], df_cdm_final['P_k'], label='CDM')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('k (Mpc$^{-1}$)')
plt.ylabel('P(k)')
plt.title('FDM Power Spectrum at t = {:.2f}'.format(t_final_cdm))
plt.grid(True)
plt.legend()
plt.savefig(output_path + 'cdm_fdm_si_power_spectrum.png', dpi=300)
plt.show()
